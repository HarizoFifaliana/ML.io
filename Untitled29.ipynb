# %%
# !wget -O /tmp/dataset.zip https://drive.google.com/uc?id=1pJovpcK9zB9CalCBQ44afKxZfvmlJq2X
# !yes | unzip /tmp/dataset.zip -d /content/dataset
# Out:
# --2024-01-12 08:03:30--  https://drive.google.com/uc?id=1pJovpcK9zB9CalCBQ44afKxZfvmlJq2X
# Resolving drive.google.com (drive.google.com)... 173.194.206.102, 173.194.206.139, 173.194.206.100, ...
# Connecting to drive.google.com (drive.google.com)|173.194.206.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1pJovpcK9zB9CalCBQ44afKxZfvmlJq2X [following]
# --2024-01-12 08:03:30--  https://drive.usercontent.google.com/download?id=1pJovpcK9zB9CalCBQ44afKxZfvmlJq2X
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.126.132, 2607:f8b0:4001:c1d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.126.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4622908 (4.4M) [application/octet-stream]
# Saving to: ‘/tmp/dataset.zip’
#
# /tmp/dataset.zip    100%[===================>]   4.41M  --.-KB/s    in 0.04s
#
# ...

# %%
# !wget -O /tmp/dataset.zip https://drive.google.com/uc?id=1lTtSA2Z0PWX16ayVWyASzwggWl-bMiWD
# !yes | unzip /tmp/dataset.zip -d /content/dataset
# Out:
# --2024-01-12 08:03:33--  https://drive.google.com/uc?id=1lTtSA2Z0PWX16ayVWyASzwggWl-bMiWD
# Resolving drive.google.com (drive.google.com)... 173.194.206.102, 173.194.206.139, 173.194.206.100, ...
# Connecting to drive.google.com (drive.google.com)|173.194.206.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1lTtSA2Z0PWX16ayVWyASzwggWl-bMiWD [following]
# --2024-01-12 08:03:33--  https://drive.usercontent.google.com/download?id=1lTtSA2Z0PWX16ayVWyASzwggWl-bMiWD
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.126.132, 2607:f8b0:4001:c1d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.126.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2349355 (2.2M) [application/octet-stream]
# Saving to: ‘/tmp/dataset.zip’
#
# /tmp/dataset.zip    100%[===================>]   2.24M  --.-KB/s    in 0.02s
#
# ...

# %%
import pandas as pd

# %%
train = pd.read_csv("dataset/train.csv")
train.head()
# Out:
#   Viewers_ID         Joke_identifier                Response_ID  Rating
# 0         A1  Klint De Drunk Enugu 1  A1_Klint De Drunk Enugu 1    0.11
# 1         A1  Klint De Drunk Enugu 2  A1_Klint De Drunk Enugu 2   -4.64
# 2         A1     Klint De Drunk PH 1     A1_Klint De Drunk PH 1   -3.39
# 3         A1     Klint De Drunk PH 2     A1_Klint De Drunk PH 2    0.44
# 4         A1  Klint De Drunk Lagos 1  A1_Klint De Drunk Lagos 1   -4.83

# %%
test = pd.read_csv("dataset/test.csv")
test.head()
# Out:
#   Viewers_ID   Joke_identifier          Response_ID
# 0         A1  Akpororo Lagos 1  A1_Akpororo Lagos 1
# 1         A1  Akpororo Abuja 1  A1_Akpororo Abuja 1
# 2         A1  Akpororo Abuja 5  A1_Akpororo Abuja 5
# 3         A1  I Go Dye Benin 1  A1_I Go Dye Benin 1
# 4         A1  I Go Dye Benin 3  A1_I Go Dye Benin 3

# %%
# Convert 'invoice_date' column to datetime for both datasets
for df in [invoice_train, invoice_test]:
    df['invoice_date'] = pd.to_datetime(df['invoice_date'])

# Encode labels in the 'counter_type' categorical column
counter_type_mapping = {"ELEC": 0, "GAZ": 1}
invoice_train['counter_type'] = invoice_train['counter_type'].map(counter_type_mapping)
invoice_test['counter_type'] = invoice_test['counter_type'].map(counter_type_mapping)

# Convert categorical columns to int for the model
client_train['client_catg'] = client_train['client_catg'].astype(int)
client_train['disrict'] = client_train['disrict'].astype(int)

client_test['client_catg'] = client_test['client_catg'].astype(int)
client_test['disrict'] = client_test['disrict'].astype(int)

# Function to aggregate invoice data by client_id
def aggregate_by_client_id(invoice_data):
    # Define aggregation functions for different columns
    aggs = {
        'consommation_level_1': ['mean'],
        'consommation_level_2': ['mean'],
        'consommation_level_3': ['mean'],
        'consommation_level_4': ['mean']
    }

    # Perform the aggregation
    agg_trans = invoice_data.groupby(['client_id']).agg(aggs)
    agg_trans.columns = ['_'.join(col).strip() for col in agg_trans.columns.values]
    agg_trans.reset_index(inplace=True)

    # Count the number of transactions for each client_id
    df = (invoice_data.groupby('client_id')
            .size()
            .reset_index(name='{}transactions_count'.format('1')))

    # Merge the aggregated data and transaction count based on client_id
    return pd.merge(df, agg_trans, on='client_id', how='left')

# Group invoice data by client_id using the defined function
agg_train = aggregate_by_client_id(invoice_train)

# Print the shape and first few rows of the aggregated data
print(agg_train.shape)
agg_train.head()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021460 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 371
# [LightGBM] [Info] Number of data points in the train set: 490161, number of used features: 2
# [LightGBM] [Info] Start training from score 0.647009
# Le RMSE sur l'ensemble de validation est : 2.511219452401707

# %%
soumission = pd.read_csv("soumission.csv")
soumission
# Out:
#                        Response_ID    Rating
# 0              A1_Akpororo Lagos 1  1.513894
# 1              A1_Akpororo Abuja 1  1.207124
# 2              A1_Akpororo Abuja 5  0.966691
# 3              A1_I Go Dye Benin 1  1.566068
# 4              A1_I Go Dye Benin 3  0.901225
# ...                            ...       ...
# 435868    A9999_Funny Bone Lagos 1  0.318705
# 435869  A9999_Okey Bakassi Lagos 2  0.318705
# 435870  A9999_Okey Bakassi Abuja 3 -1.292258
# 435871     A9999_MisterIbu Lagos 1 -1.292258
# 435872     A9999_MisterIbu Lagos 4 -1.292258
#
# [435873 rows x 2 columns]

# %%
train['Viewers_ID'].unique
# Out:
# <bound method Series.unique of 0             0
# 1             0
# 2             0
# 3             0
# 4             0
#           ...
# 612697    40862
# 612698    40862
# 612699    40862
# 612700    40862
# 612701    40862
# Name: Viewers_ID, Length: 612702, dtype: int64>
